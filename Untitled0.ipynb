# %%
# !pip install numpy
# !pip install matplotlib
# !pip install pillow
# !pip install scikit-learn
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from sklearn import preprocessing
from sklearn.preprocessing import scale
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from keras.optimizers import Adam

# %%
len_trainData = int( 194 * 0.8)
len_testData = int( 194 * 0.2)

image_sizeX = 128
image_sizeY = 128


train_data = []
train_mask1 = []
train_mask2 = []

test_data = []
test_mask1 = []
test_mask2 = []

# %%
for i in range(len_trainData - 1):
    x = mpimg.imread('/content/drive/MyDrive/GPR/dataset/data/%d.png'%(i+1))

    x = x.reshape(image_sizeX,image_sizeY,1)

    train_data.append(x)



    m1 = mpimg.imread('/content/drive/MyDrive/GPR/dataset/mask1/%d.png'%(i+1))
    m1 = m1.reshape(image_sizeX,image_sizeY,1)
    train_mask1.append(m1)
    m2 = mpimg.imread('/content/drive/MyDrive/GPR/dataset/mask2/%d.png'%(i+1))
    m2 = m2.reshape(image_sizeX,image_sizeY,1)
    train_mask2.append(m2)


for i in range(len_trainData, len_trainData + len_testData):
    x = mpimg.imread('/content/drive/MyDrive/GPR/dataset/data/%d.png'%(i+1))
    x = x.reshape(image_sizeX,image_sizeY,1)
    test_data.append(x)

    m1 = mpimg.imread('/content/drive/MyDrive/GPR/dataset/mask1/%d.png'%(i+1))
    m1 = m1.reshape(image_sizeX,image_sizeY,1)
    test_mask1.append(m1)

    m2 = mpimg.imread('/content/drive/MyDrive/GPR/dataset/mask2/%d.png'%(i+1))
    m2 = m2.reshape(image_sizeX,image_sizeY,1)
    test_mask2.append(m2)

# %%
train_data = np.array(train_data)
train_mask1 = np.array(train_mask1)
train_mask2 = np.array(train_mask2)
test_data = np.array(test_data)
test_mask1 = np.array(test_mask1)
test_mask2 = np.array(test_mask2)

# %%
def multi_scale(x, filters, padding="same", strides=1):

    c1 = keras.layers.Conv2D(filters, (1,1), padding=padding, strides=strides, activation="relu")(x)

    c3 = keras.layers.Conv2D(filters, (3,3), padding=padding, strides=strides, activation="relu")(x)

    c5 = keras.layers.Conv2D(filters, (5,5), padding=padding, strides=strides, activation="relu")(x)

    c7 = keras.layers.Conv2D(filters, (7,7), padding=padding, strides=strides, activation="relu")(x)

    c = keras.layers.Concatenate()([c1, c3, c5, c7])
    return c

def down_block2(x, filters, kernel_size=(3, 3), padding="same", strides=1):

    f = int(filters/4)

    c = multi_scale(x, f)

    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)

    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p


def up_block2(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):

    f = int(filters/4)

    us = keras.layers.UpSampling2D((2, 2))(x)

    us = keras.layers.Conv2D(filters, (2, 2), padding='same', strides=1, activation="relu")(us)

    c = keras.layers.Concatenate()([us, skip])

    c = multi_scale(c, f)

    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c


def bottleneck2(x, filters, kernel_size=(3, 3), padding="same", strides=1):

    f = int(filters/4)

    c = multi_scale(x, f)

    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def DMRF_UNet():

    f0 = 64
    f = [f0, f0*2, f0*4, f0*8, f0*16]
    inputs = keras.layers.Input((image_sizeX, image_sizeY, 1))

   #model1
    p0 = inputs
    c1, p1 = down_block2(p0, f[0])
    c2, p2 = down_block2(p1, f[1])
    c3, p3 = down_block2(p2, f[2])
    c4, p4 = down_block2(p3, f[3])

    bn = bottleneck2(p4, f[4])

    u1 = up_block2(bn, c4, f[3])
    u2 = up_block2(u1, c3, f[2])
    u3 = up_block2(u2, c2, f[1])
    u4 = up_block2(u3, c1, f[0])

    output_1 = keras.layers.Conv2D(1, (1, 1), padding="same", activation="relu")(u4)
    model_1 = tf.keras.Model(inputs, output_1)

    #model2
    pp0 = keras.layers.Concatenate()([output_1, inputs])
    cc1, pp1 = down_block2(pp0, f[0])
    cc2, pp2 = down_block2(pp1, f[1])
    cc3, pp3 = down_block2(pp2, f[2])
    cc4, pp4 = down_block2(pp3, f[3])

    bnn = bottleneck2(pp4, f[4])

    uu1 = up_block2(bnn, cc4, f[3])
    uu2 = up_block2(uu1, cc3, f[2])
    uu3 = up_block2(uu2, cc2, f[1])
    uu4 = up_block2(uu3, cc1, f[0])

    output_2 = keras.layers.Conv2D(1, (1, 1), padding="same", activation="elu")(uu4)
    model_2 = tf.keras.Model(inputs, [output_1, output_2])

    return model_2

def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr
    return lr

model = DMRF_UNet()

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 16)   │             32 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 16)   │            160 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 16)   │            416 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 16)   │            800 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128, 128, 64)   │              0 │ conv2d[0][0],          │
# │                           │                        │                │ conv2d_1[0][0],        │
# │                           │                        │                │ conv2d_2[0][0],        │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 128, 128, 64)   │         36,928 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 64)     │              0 │ conv2d_4[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 32)     │          2,080 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 32)     │         18,464 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 32)     │         51,232 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 64, 32)     │        100,384 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 128)    │              0 │ conv2d_5[0][0],        │
# │ (Concatenate)             │                        │                │ conv2d_6[0][0],        │
# │                           │                        │                │ conv2d_7[0][0],        │
# │                           │                        │                │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 64, 64, 128)    │        147,584 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 128)    │              0 │ conv2d_9[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 64)     │          8,256 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 64)     │        204,864 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 64)     │        401,472 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 32, 256)    │              0 │ conv2d_10[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_11[0][0],       │
# │                           │                        │                │ conv2d_12[0][0],       │
# │                           │                        │                │ conv2d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 256)    │              0 │ conv2d_14[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 16, 16, 128)    │         32,896 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 16, 16, 128)    │        295,040 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 16, 16, 128)    │        819,328 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 16, 16, 128)    │      1,605,760 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 16, 16, 512)    │              0 │ conv2d_15[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_16[0][0],       │
# │                           │                        │                │ conv2d_17[0][0],       │
# │                           │                        │                │ conv2d_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 8, 8, 512)      │              0 │ conv2d_19[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 8, 8, 256)      │        131,328 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 8, 8, 256)      │      1,179,904 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 8, 8, 256)      │      3,277,056 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 8, 8, 256)      │      6,422,784 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 8, 8, 1024)     │              0 │ conv2d_20[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_21[0][0],       │
# │                           │                        │                │ conv2d_22[0][0],       │
# │                           │                        │                │ conv2d_23[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 16, 16, 1024)   │              0 │ conv2d_24[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 16, 16, 512)    │      2,097,664 │ up_sampling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 16, 16, 1024)   │              0 │ conv2d_25[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 16, 16, 128)    │        131,200 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 16, 16, 128)    │      1,179,776 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 16, 16, 128)    │      3,276,928 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 16, 16, 128)    │      6,422,656 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 16, 16, 512)    │              0 │ conv2d_26[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_27[0][0],       │
# │                           │                        │                │ conv2d_28[0][0],       │
# │                           │                        │                │ conv2d_29[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 32, 32, 512)    │              0 │ conv2d_30[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 32, 32, 256)    │        524,544 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 32, 32, 512)    │              0 │ conv2d_31[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 32, 32, 64)     │         32,832 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 32, 32, 64)     │        294,976 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 32, 32, 64)     │        819,264 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 32, 32, 64)     │      1,605,696 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 32, 32, 256)    │              0 │ conv2d_32[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_33[0][0],       │
# │                           │                        │                │ conv2d_34[0][0],       │
# │                           │                        │                │ conv2d_35[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 256)    │              0 │ conv2d_36[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 64, 64, 128)    │        131,200 │ up_sampling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 64, 64, 256)    │              0 │ conv2d_37[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 64, 64, 32)     │          8,224 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 64, 64, 32)     │         73,760 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 64, 64, 32)     │        204,832 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 64, 64, 32)     │        401,440 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 64, 64, 128)    │              0 │ conv2d_38[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_39[0][0],       │
# │                           │                        │                │ conv2d_40[0][0],       │
# │                           │                        │                │ conv2d_41[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 128)  │              0 │ conv2d_42[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 128, 128, 64)   │         32,832 │ up_sampling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 128, 128, 128)  │              0 │ conv2d_43[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 128, 128, 16)   │          2,064 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 128, 128, 16)   │         18,448 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 128, 128, 16)   │         51,216 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 128, 128, 16)   │        100,368 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_12            │ (None, 128, 128, 64)   │              0 │ conv2d_44[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_45[0][0],       │
# │                           │                        │                │ conv2d_46[0][0],       │
# │                           │                        │                │ conv2d_47[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ concatenate_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 128, 128, 1)    │             65 │ conv2d_48[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_13            │ (None, 128, 128, 2)    │              0 │ conv2d_49[0][0],       │
# │ (Concatenate)             │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 128, 128, 16)   │             48 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 128, 128, 16)   │            304 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 128, 128, 16)   │            816 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 128, 128, 16)   │          1,584 │ concatenate_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_14            │ (None, 128, 128, 64)   │              0 │ conv2d_50[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_51[0][0],       │
# │                           │                        │                │ conv2d_52[0][0],       │
# │                           │                        │                │ conv2d_53[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ concatenate_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 64, 64, 64)     │              0 │ conv2d_54[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 64, 64, 32)     │          2,080 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 64, 64, 32)     │         18,464 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_57 (Conv2D)        │ (None, 64, 64, 32)     │         51,232 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_58 (Conv2D)        │ (None, 64, 64, 32)     │        100,384 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_15            │ (None, 64, 64, 128)    │              0 │ conv2d_55[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_56[0][0],       │
# │                           │                        │                │ conv2d_57[0][0],       │
# │                           │                        │                │ conv2d_58[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_59 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ concatenate_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 32, 32, 128)    │              0 │ conv2d_59[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_60 (Conv2D)        │ (None, 32, 32, 64)     │          8,256 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_61 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_62 (Conv2D)        │ (None, 32, 32, 64)     │        204,864 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 32, 32, 64)     │        401,472 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_16            │ (None, 32, 32, 256)    │              0 │ conv2d_60[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_61[0][0],       │
# │                           │                        │                │ conv2d_62[0][0],       │
# │                           │                        │                │ conv2d_63[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_64 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ concatenate_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_6           │ (None, 16, 16, 256)    │              0 │ conv2d_64[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_65 (Conv2D)        │ (None, 16, 16, 128)    │         32,896 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_66 (Conv2D)        │ (None, 16, 16, 128)    │        295,040 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_67 (Conv2D)        │ (None, 16, 16, 128)    │        819,328 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 16, 16, 128)    │      1,605,760 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_17            │ (None, 16, 16, 512)    │              0 │ conv2d_65[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_66[0][0],       │
# │                           │                        │                │ conv2d_67[0][0],       │
# │                           │                        │                │ conv2d_68[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ concatenate_17[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_7           │ (None, 8, 8, 512)      │              0 │ conv2d_69[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 8, 8, 256)      │        131,328 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 8, 8, 256)      │      1,179,904 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_72 (Conv2D)        │ (None, 8, 8, 256)      │      3,277,056 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_73 (Conv2D)        │ (None, 8, 8, 256)      │      6,422,784 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_18            │ (None, 8, 8, 1024)     │              0 │ conv2d_70[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_71[0][0],       │
# │                           │                        │                │ conv2d_72[0][0],       │
# │                           │                        │                │ conv2d_73[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_74 (Conv2D)        │ (None, 8, 8, 1024)     │      9,438,208 │ concatenate_18[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 16, 16, 1024)   │              0 │ conv2d_74[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_75 (Conv2D)        │ (None, 16, 16, 512)    │      2,097,664 │ up_sampling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_19            │ (None, 16, 16, 1024)   │              0 │ conv2d_75[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_69[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_76 (Conv2D)        │ (None, 16, 16, 128)    │        131,200 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_77 (Conv2D)        │ (None, 16, 16, 128)    │      1,179,776 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_78 (Conv2D)        │ (None, 16, 16, 128)    │      3,276,928 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_79 (Conv2D)        │ (None, 16, 16, 128)    │      6,422,656 │ concatenate_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_20            │ (None, 16, 16, 512)    │              0 │ conv2d_76[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_77[0][0],       │
# │                           │                        │                │ conv2d_78[0][0],       │
# │                           │                        │                │ conv2d_79[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_80 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ concatenate_20[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_5           │ (None, 32, 32, 512)    │              0 │ conv2d_80[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_81 (Conv2D)        │ (None, 32, 32, 256)    │        524,544 │ up_sampling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_21            │ (None, 32, 32, 512)    │              0 │ conv2d_81[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_64[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_82 (Conv2D)        │ (None, 32, 32, 64)     │         32,832 │ concatenate_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_83 (Conv2D)        │ (None, 32, 32, 64)     │        294,976 │ concatenate_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_84 (Conv2D)        │ (None, 32, 32, 64)     │        819,264 │ concatenate_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_85 (Conv2D)        │ (None, 32, 32, 64)     │      1,605,696 │ concatenate_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_22            │ (None, 32, 32, 256)    │              0 │ conv2d_82[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_83[0][0],       │
# │                           │                        │                │ conv2d_84[0][0],       │
# │                           │                        │                │ conv2d_85[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_86 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ concatenate_22[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_6           │ (None, 64, 64, 256)    │              0 │ conv2d_86[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_87 (Conv2D)        │ (None, 64, 64, 128)    │        131,200 │ up_sampling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_23            │ (None, 64, 64, 256)    │              0 │ conv2d_87[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_59[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_88 (Conv2D)        │ (None, 64, 64, 32)     │          8,224 │ concatenate_23[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_89 (Conv2D)        │ (None, 64, 64, 32)     │         73,760 │ concatenate_23[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_90 (Conv2D)        │ (None, 64, 64, 32)     │        204,832 │ concatenate_23[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_91 (Conv2D)        │ (None, 64, 64, 32)     │        401,440 │ concatenate_23[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_24            │ (None, 64, 64, 128)    │              0 │ conv2d_88[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_89[0][0],       │
# │                           │                        │                │ conv2d_90[0][0],       │
# │                           │                        │                │ conv2d_91[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_92 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ concatenate_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_7           │ (None, 128, 128, 128)  │              0 │ conv2d_92[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_93 (Conv2D)        │ (None, 128, 128, 64)   │         32,832 │ up_sampling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_25            │ (None, 128, 128, 128)  │              0 │ conv2d_93[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_54[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_94 (Conv2D)        │ (None, 128, 128, 16)   │          2,064 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_95 (Conv2D)        │ (None, 128, 128, 16)   │         18,448 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_96 (Conv2D)        │ (None, 128, 128, 16)   │         51,216 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_97 (Conv2D)        │ (None, 128, 128, 16)   │        100,368 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_26            │ (None, 128, 128, 64)   │              0 │ conv2d_94[0][0],       │
# │ (Concatenate)             │                        │                │ conv2d_95[0][0],       │
# │                           │                        │                │ conv2d_96[0][0],       │
# │                           │                        │                │ conv2d_97[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_98 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ concatenate_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_99 (Conv2D)        │ (None, 128, 128, 1)    │             65 │ conv2d_98[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 95,487,426 (364.26 MB)
#  Trainable params: 95,487,426 (364.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
total_epoch = 50
batch_size = 50
alpha = 10
beta = 1
path = './'
model_path = '/content/drive/MyDrive/GPR/tar/models.keras'
Adam = keras.optimizers.Adam(learning_rate=1e-4)
lr_metric = get_lr_metric(Adam)
model.compile(optimizer=Adam, loss=['mse', 'mse'], loss_weights=[alpha, beta], metrics=['mae', 'mae'])
model_checkpoint = keras.callbacks.ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True)
lr_checkpoint = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.95, patience=2, min_lr=0)
history = model.fit(x=train_data, y=[train_mask1, train_mask2], batch_size=batch_size, epochs=total_epoch, verbose=2, \
    validation_data=(test_data, [test_mask1, test_mask2]), callbacks=[model_checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.09416, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 78s - 19s/step - conv2d_49_loss: 0.0902 - conv2d_49_mae: 0.0739 - conv2d_99_loss: 0.0021 - conv2d_99_mae: 0.0161 - loss: 0.1005 - val_conv2d_49_loss: 0.0923 - val_conv2d_49_mae: 0.0883 - val_conv2d_99_loss: 0.0018 - val_conv2d_99_mae: 0.0221 - val_loss: 0.0942
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.09416 to 0.02747, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 22s - 6s/step - conv2d_49_loss: 0.0760 - conv2d_49_mae: 0.0842 - conv2d_99_loss: 0.0027 - conv2d_99_mae: 0.0191 - loss: 0.0870 - val_conv2d_49_loss: 0.0258 - val_conv2d_49_mae: 0.0380 - val_conv2d_99_loss: 0.0017 - val_conv2d_99_mae: 0.0137 - val_loss: 0.0275
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 0.02747
# 4/4 - 28s - 7s/step - conv2d_49_loss: 0.0383 - conv2d_49_mae: 0.0483 - conv2d_99_loss: 0.0020 - conv2d_99_mae: 0.0139 - loss: 0.0403 - val_conv2d_49_loss: 0.0277 - val_conv2d_49_mae: 0.0411 - val_conv2d_99_loss: 0.0017 - val_conv2d_99_mae: 0.0161 - val_loss: 0.0294
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.02747
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0231 - conv2d_49_mae: 0.0356 - conv2d_99_loss: 0.0021 - conv2d_99_mae: 0.0132 - loss: 0.0253 - val_conv2d_49_loss: 0.0276 - val_conv2d_49_mae: 0.0406 - val_conv2d_99_loss: 0.0016 - val_conv2d_99_mae: 0.0137 - val_loss: 0.0292
# Epoch 5/50
#
# Epoch 5: val_loss improved from 0.02747 to 0.02298, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 18s - 5s/step - conv2d_49_loss: 0.0253 - conv2d_49_mae: 0.0394 - conv2d_99_loss: 0.0020 - conv2d_99_mae: 0.0098 - loss: 0.0284 - val_conv2d_49_loss: 0.0216 - val_conv2d_49_mae: 0.0349 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0076 - val_loss: 0.0230
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.02298
# 4/4 - 12s - 3s/step - conv2d_49_loss: 0.0204 - conv2d_49_mae: 0.0318 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0080 - loss: 0.0215 - val_conv2d_49_loss: 0.0230 - val_conv2d_49_mae: 0.0370 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0065 - val_loss: 0.0244
# Epoch 7/50
#
# Epoch 7: val_loss improved from 0.02298 to 0.02167, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 27s - 7s/step - conv2d_49_loss: 0.0207 - conv2d_49_mae: 0.0327 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0082 - loss: 0.0220 - val_conv2d_49_loss: 0.0203 - val_conv2d_49_mae: 0.0339 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0065 - val_loss: 0.0217
# Epoch 8/50
#
# Epoch 8: val_loss improved from 0.02167 to 0.02119, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 36s - 9s/step - conv2d_49_loss: 0.0187 - conv2d_49_mae: 0.0315 - conv2d_99_loss: 0.0018 - conv2d_99_mae: 0.0078 - loss: 0.0210 - val_conv2d_49_loss: 0.0198 - val_conv2d_49_mae: 0.0334 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0094 - val_loss: 0.0212
# Epoch 9/50
#
# Epoch 9: val_loss improved from 0.02119 to 0.02098, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 22s - 6s/step - conv2d_49_loss: 0.0186 - conv2d_49_mae: 0.0301 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0075 - loss: 0.0198 - val_conv2d_49_loss: 0.0197 - val_conv2d_49_mae: 0.0337 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0075 - val_loss: 0.0210
# Epoch 10/50
#
# Epoch 10: val_loss improved from 0.02098 to 0.02006, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 42s - 11s/step - conv2d_49_loss: 0.0185 - conv2d_49_mae: 0.0314 - conv2d_99_loss: 0.0022 - conv2d_99_mae: 0.0070 - loss: 0.0205 - val_conv2d_49_loss: 0.0186 - val_conv2d_49_mae: 0.0325 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0076 - val_loss: 0.0201
# Epoch 11/50
#
# Epoch 11: val_loss improved from 0.02006 to 0.01928, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 35s - 9s/step - conv2d_49_loss: 0.0169 - conv2d_49_mae: 0.0293 - conv2d_99_loss: 0.0016 - conv2d_99_mae: 0.0072 - loss: 0.0189 - val_conv2d_49_loss: 0.0179 - val_conv2d_49_mae: 0.0319 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0048 - val_loss: 0.0193
# Epoch 12/50
#
# Epoch 12: val_loss improved from 0.01928 to 0.01872, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 25s - 6s/step - conv2d_49_loss: 0.0175 - conv2d_49_mae: 0.0288 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0057 - loss: 0.0181 - val_conv2d_49_loss: 0.0174 - val_conv2d_49_mae: 0.0315 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0059 - val_loss: 0.0187
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.01872
# 4/4 - 28s - 7s/step - conv2d_49_loss: 0.0151 - conv2d_49_mae: 0.0292 - conv2d_99_loss: 0.0018 - conv2d_99_mae: 0.0065 - loss: 0.0179 - val_conv2d_49_loss: 0.0174 - val_conv2d_49_mae: 0.0316 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0087 - val_loss: 0.0188
# Epoch 14/50
#
# Epoch 14: val_loss improved from 0.01872 to 0.01822, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 17s - 4s/step - conv2d_49_loss: 0.0153 - conv2d_49_mae: 0.0287 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0086 - loss: 0.0173 - val_conv2d_49_loss: 0.0169 - val_conv2d_49_mae: 0.0311 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0097 - val_loss: 0.0182
# Epoch 15/50
#
# Epoch 15: val_loss improved from 0.01822 to 0.01796, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 22s - 5s/step - conv2d_49_loss: 0.0154 - conv2d_49_mae: 0.0281 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0095 - loss: 0.0167 - val_conv2d_49_loss: 0.0166 - val_conv2d_49_mae: 0.0308 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0099 - val_loss: 0.0180
# Epoch 16/50
#
# Epoch 16: val_loss improved from 0.01796 to 0.01793, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 20s - 5s/step - conv2d_49_loss: 0.0180 - conv2d_49_mae: 0.0289 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0111 - loss: 0.0174 - val_conv2d_49_loss: 0.0165 - val_conv2d_49_mae: 0.0307 - val_conv2d_99_loss: 0.0015 - val_conv2d_99_mae: 0.0122 - val_loss: 0.0179
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.01793
# 4/4 - 13s - 3s/step - conv2d_49_loss: 0.0148 - conv2d_49_mae: 0.0295 - conv2d_99_loss: 0.0021 - conv2d_99_mae: 0.0131 - loss: 0.0176 - val_conv2d_49_loss: 0.0188 - val_conv2d_49_mae: 0.0332 - val_conv2d_99_loss: 0.0029 - val_conv2d_99_mae: 0.0180 - val_loss: 0.0217
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.01793
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0138 - conv2d_49_mae: 0.0280 - conv2d_99_loss: 0.0023 - conv2d_99_mae: 0.0148 - loss: 0.0169 - val_conv2d_49_loss: 0.0176 - val_conv2d_49_mae: 0.0324 - val_conv2d_99_loss: 0.0016 - val_conv2d_99_mae: 0.0054 - val_loss: 0.0192
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.01793
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0149 - conv2d_49_mae: 0.0281 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0083 - loss: 0.0169 - val_conv2d_49_loss: 0.0175 - val_conv2d_49_mae: 0.0318 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0068 - val_loss: 0.0188
# Epoch 20/50
#
# Epoch 20: val_loss improved from 0.01793 to 0.01745, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 18s - 4s/step - conv2d_49_loss: 0.0146 - conv2d_49_mae: 0.0298 - conv2d_99_loss: 0.0023 - conv2d_99_mae: 0.0098 - loss: 0.0179 - val_conv2d_49_loss: 0.0161 - val_conv2d_49_mae: 0.0303 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0108 - val_loss: 0.0175
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.01745
# 4/4 - 9s - 2s/step - conv2d_49_loss: 0.0134 - conv2d_49_mae: 0.0274 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0085 - loss: 0.0161 - val_conv2d_49_loss: 0.0168 - val_conv2d_49_mae: 0.0319 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0094 - val_loss: 0.0181
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.01745
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0148 - conv2d_49_mae: 0.0274 - conv2d_99_loss: 0.0019 - conv2d_99_mae: 0.0087 - loss: 0.0158 - val_conv2d_49_loss: 0.0175 - val_conv2d_49_mae: 0.0320 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0067 - val_loss: 0.0188
# Epoch 23/50
#
# Epoch 23: val_loss improved from 0.01745 to 0.01706, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 26s - 7s/step - conv2d_49_loss: 0.0163 - conv2d_49_mae: 0.0302 - conv2d_99_loss: 0.0018 - conv2d_99_mae: 0.0079 - loss: 0.0176 - val_conv2d_49_loss: 0.0158 - val_conv2d_49_mae: 0.0302 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0079 - val_loss: 0.0171
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.01706
# 4/4 - 25s - 6s/step - conv2d_49_loss: 0.0145 - conv2d_49_mae: 0.0287 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0075 - loss: 0.0164 - val_conv2d_49_loss: 0.0162 - val_conv2d_49_mae: 0.0313 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0085 - val_loss: 0.0174
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.01706
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0145 - conv2d_49_mae: 0.0272 - conv2d_99_loss: 0.0017 - conv2d_99_mae: 0.0076 - loss: 0.0155 - val_conv2d_49_loss: 0.0162 - val_conv2d_49_mae: 0.0306 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0080 - val_loss: 0.0174
# Epoch 26/50
#
# Epoch 26: val_loss improved from 0.01706 to 0.01685, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 22s - 5s/step - conv2d_49_loss: 0.0136 - conv2d_49_mae: 0.0268 - conv2d_99_loss: 0.0016 - conv2d_99_mae: 0.0091 - loss: 0.0152 - val_conv2d_49_loss: 0.0156 - val_conv2d_49_mae: 0.0305 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0061 - val_loss: 0.0168
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.01685
# 4/4 - 10s - 2s/step - conv2d_49_loss: 0.0128 - conv2d_49_mae: 0.0268 - conv2d_99_loss: 0.0015 - conv2d_99_mae: 0.0084 - loss: 0.0150 - val_conv2d_49_loss: 0.0158 - val_conv2d_49_mae: 0.0301 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0062 - val_loss: 0.0169
# Epoch 28/50
#
# Epoch 28: val_loss improved from 0.01685 to 0.01583, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 22s - 5s/step - conv2d_49_loss: 0.0143 - conv2d_49_mae: 0.0271 - conv2d_99_loss: 0.0015 - conv2d_99_mae: 0.0080 - loss: 0.0151 - val_conv2d_49_loss: 0.0145 - val_conv2d_49_mae: 0.0290 - val_conv2d_99_loss: 0.0014 - val_conv2d_99_mae: 0.0085 - val_loss: 0.0158
# Epoch 29/50
#
# Epoch 29: val_loss improved from 0.01583 to 0.01542, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 40s - 10s/step - conv2d_49_loss: 0.0144 - conv2d_49_mae: 0.0255 - conv2d_99_loss: 0.0018 - conv2d_99_mae: 0.0071 - loss: 0.0141 - val_conv2d_49_loss: 0.0141 - val_conv2d_49_mae: 0.0286 - val_conv2d_99_loss: 0.0013 - val_conv2d_99_mae: 0.0101 - val_loss: 0.0154
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.01542
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0115 - conv2d_49_mae: 0.0258 - conv2d_99_loss: 0.0020 - conv2d_99_mae: 0.0096 - loss: 0.0140 - val_conv2d_49_loss: 0.0146 - val_conv2d_49_mae: 0.0288 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0091 - val_loss: 0.0158
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.01542
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0119 - conv2d_49_mae: 0.0252 - conv2d_99_loss: 0.0014 - conv2d_99_mae: 0.0112 - loss: 0.0136 - val_conv2d_49_loss: 0.0145 - val_conv2d_49_mae: 0.0295 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0065 - val_loss: 0.0156
# Epoch 32/50
#
# Epoch 32: val_loss improved from 0.01542 to 0.01494, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 21s - 5s/step - conv2d_49_loss: 0.0123 - conv2d_49_mae: 0.0255 - conv2d_99_loss: 0.0016 - conv2d_99_mae: 0.0096 - loss: 0.0136 - val_conv2d_49_loss: 0.0138 - val_conv2d_49_mae: 0.0282 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0058 - val_loss: 0.0149
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.01494
# 4/4 - 30s - 7s/step - conv2d_49_loss: 0.0105 - conv2d_49_mae: 0.0248 - conv2d_99_loss: 0.0015 - conv2d_99_mae: 0.0080 - loss: 0.0130 - val_conv2d_49_loss: 0.0141 - val_conv2d_49_mae: 0.0283 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0085 - val_loss: 0.0152
# Epoch 34/50
#
# Epoch 34: val_loss improved from 0.01494 to 0.01492, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 24s - 6s/step - conv2d_49_loss: 0.0122 - conv2d_49_mae: 0.0242 - conv2d_99_loss: 0.0015 - conv2d_99_mae: 0.0079 - loss: 0.0128 - val_conv2d_49_loss: 0.0138 - val_conv2d_49_mae: 0.0281 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0080 - val_loss: 0.0149
# Epoch 35/50
#
# Epoch 35: val_loss improved from 0.01492 to 0.01408, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 38s - 9s/step - conv2d_49_loss: 0.0102 - conv2d_49_mae: 0.0247 - conv2d_99_loss: 0.0014 - conv2d_99_mae: 0.0072 - loss: 0.0128 - val_conv2d_49_loss: 0.0130 - val_conv2d_49_mae: 0.0274 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0084 - val_loss: 0.0141
# Epoch 36/50
#
# Epoch 36: val_loss improved from 0.01408 to 0.01397, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 42s - 11s/step - conv2d_49_loss: 0.0117 - conv2d_49_mae: 0.0238 - conv2d_99_loss: 0.0013 - conv2d_99_mae: 0.0073 - loss: 0.0122 - val_conv2d_49_loss: 0.0130 - val_conv2d_49_mae: 0.0276 - val_conv2d_99_loss: 9.8232e-04 - val_conv2d_99_mae: 0.0073 - val_loss: 0.0140
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.01397
# 4/4 - 29s - 7s/step - conv2d_49_loss: 0.0100 - conv2d_49_mae: 0.0238 - conv2d_99_loss: 0.0013 - conv2d_99_mae: 0.0074 - loss: 0.0121 - val_conv2d_49_loss: 0.0131 - val_conv2d_49_mae: 0.0275 - val_conv2d_99_loss: 9.3726e-04 - val_conv2d_99_mae: 0.0062 - val_loss: 0.0141
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.01397
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0103 - conv2d_49_mae: 0.0236 - conv2d_99_loss: 0.0012 - conv2d_99_mae: 0.0074 - loss: 0.0119 - val_conv2d_49_loss: 0.0134 - val_conv2d_49_mae: 0.0275 - val_conv2d_99_loss: 8.6913e-04 - val_conv2d_99_mae: 0.0053 - val_loss: 0.0143
# Epoch 39/50
#
# Epoch 39: val_loss improved from 0.01397 to 0.01393, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 21s - 5s/step - conv2d_49_loss: 0.0096 - conv2d_49_mae: 0.0241 - conv2d_99_loss: 0.0013 - conv2d_99_mae: 0.0065 - loss: 0.0121 - val_conv2d_49_loss: 0.0127 - val_conv2d_49_mae: 0.0269 - val_conv2d_99_loss: 0.0012 - val_conv2d_99_mae: 0.0057 - val_loss: 0.0139
# Epoch 40/50
#
# Epoch 40: val_loss improved from 0.01393 to 0.01334, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 41s - 10s/step - conv2d_49_loss: 0.0090 - conv2d_49_mae: 0.0233 - conv2d_99_loss: 0.0015 - conv2d_99_mae: 0.0062 - loss: 0.0120 - val_conv2d_49_loss: 0.0125 - val_conv2d_49_mae: 0.0264 - val_conv2d_99_loss: 8.7720e-04 - val_conv2d_99_mae: 0.0045 - val_loss: 0.0133
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.01334
# 4/4 - 30s - 8s/step - conv2d_49_loss: 0.0098 - conv2d_49_mae: 0.0227 - conv2d_99_loss: 0.0012 - conv2d_99_mae: 0.0055 - loss: 0.0113 - val_conv2d_49_loss: 0.0123 - val_conv2d_49_mae: 0.0263 - val_conv2d_99_loss: 0.0011 - val_conv2d_99_mae: 0.0050 - val_loss: 0.0134
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.01334
# 4/4 - 10s - 2s/step - conv2d_49_loss: 0.0103 - conv2d_49_mae: 0.0232 - conv2d_99_loss: 0.0013 - conv2d_99_mae: 0.0054 - loss: 0.0117 - val_conv2d_49_loss: 0.0127 - val_conv2d_49_mae: 0.0273 - val_conv2d_99_loss: 9.2365e-04 - val_conv2d_99_mae: 0.0061 - val_loss: 0.0136
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.01334
# 4/4 - 10s - 3s/step - conv2d_49_loss: 0.0129 - conv2d_49_mae: 0.0246 - conv2d_99_loss: 0.0012 - conv2d_99_mae: 0.0059 - loss: 0.0122 - val_conv2d_49_loss: 0.0134 - val_conv2d_49_mae: 0.0278 - val_conv2d_99_loss: 9.4606e-04 - val_conv2d_99_mae: 0.0073 - val_loss: 0.0143
# Epoch 44/50
#
# Epoch 44: val_loss improved from 0.01334 to 0.01330, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 23s - 6s/step - conv2d_49_loss: 0.0119 - conv2d_49_mae: 0.0257 - conv2d_99_loss: 0.0011 - conv2d_99_mae: 0.0064 - loss: 0.0128 - val_conv2d_49_loss: 0.0124 - val_conv2d_49_mae: 0.0268 - val_conv2d_99_loss: 8.4990e-04 - val_conv2d_99_mae: 0.0082 - val_loss: 0.0133
# Epoch 45/50
#
# Epoch 45: val_loss improved from 0.01330 to 0.01306, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 41s - 10s/step - conv2d_49_loss: 0.0113 - conv2d_49_mae: 0.0246 - conv2d_99_loss: 0.0011 - conv2d_99_mae: 0.0066 - loss: 0.0122 - val_conv2d_49_loss: 0.0120 - val_conv2d_49_mae: 0.0262 - val_conv2d_99_loss: 0.0010 - val_conv2d_99_mae: 0.0083 - val_loss: 0.0131
# Epoch 46/50
#
# Epoch 46: val_loss improved from 0.01306 to 0.01303, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 37s - 9s/step - conv2d_49_loss: 0.0100 - conv2d_49_mae: 0.0229 - conv2d_99_loss: 0.0012 - conv2d_99_mae: 0.0065 - loss: 0.0112 - val_conv2d_49_loss: 0.0121 - val_conv2d_49_mae: 0.0265 - val_conv2d_99_loss: 9.2978e-04 - val_conv2d_99_mae: 0.0082 - val_loss: 0.0130
# Epoch 47/50
#
# Epoch 47: val_loss improved from 0.01303 to 0.01267, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 21s - 5s/step - conv2d_49_loss: 0.0107 - conv2d_49_mae: 0.0239 - conv2d_99_loss: 0.0011 - conv2d_99_mae: 0.0069 - loss: 0.0115 - val_conv2d_49_loss: 0.0117 - val_conv2d_49_mae: 0.0260 - val_conv2d_99_loss: 9.4613e-04 - val_conv2d_99_mae: 0.0083 - val_loss: 0.0127
# Epoch 48/50
#
# Epoch 48: val_loss improved from 0.01267 to 0.01255, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 23s - 6s/step - conv2d_49_loss: 0.0091 - conv2d_49_mae: 0.0225 - conv2d_99_loss: 0.0011 - conv2d_99_mae: 0.0073 - loss: 0.0109 - val_conv2d_49_loss: 0.0117 - val_conv2d_49_mae: 0.0257 - val_conv2d_99_loss: 8.3744e-04 - val_conv2d_99_mae: 0.0072 - val_loss: 0.0125
# Epoch 49/50
#
# Epoch 49: val_loss improved from 0.01255 to 0.01235, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 40s - 10s/step - conv2d_49_loss: 0.0092 - conv2d_49_mae: 0.0223 - conv2d_99_loss: 0.0010 - conv2d_99_mae: 0.0069 - loss: 0.0106 - val_conv2d_49_loss: 0.0114 - val_conv2d_49_mae: 0.0256 - val_conv2d_99_loss: 9.2165e-04 - val_conv2d_99_mae: 0.0055 - val_loss: 0.0124
# Epoch 50/50
#
# Epoch 50: val_loss improved from 0.01235 to 0.01227, saving model to /content/drive/MyDrive/GPR/tar/models.keras
# 4/4 - 45s - 11s/step - conv2d_49_loss: 0.0097 - conv2d_49_mae: 0.0218 - conv2d_99_loss: 0.0010 - conv2d_99_mae: 0.0063 - loss: 0.0102 - val_conv2d_49_loss: 0.0114 - val_conv2d_49_mae: 0.0254 - val_conv2d_99_loss: 8.5935e-04 - val_conv2d_99_mae: 0.0046 - val_loss: 0.0123

# %%
pred_masks = model.predict(test_data)

pred_mask1 = pred_masks[0]
pred_mask2 = pred_masks[1]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step

# %%
import cv2

def get_bounding_boxes(mask, threshold=0.5):

    mask = (mask > threshold).astype(np.uint8) * 255

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    bounding_boxes = []

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        bounding_boxes.append((x, y, w, h))

    return bounding_boxes

for i in range(len(test_data)):
    pred1 = pred_mask1[i].reshape(image_sizeX, image_sizeY)

    boxes = get_bounding_boxes(pred1)

    img = test_data[i].reshape(image_sizeX, image_sizeY) * 255

    img = cv2.cvtColor(img.astype(np.uint8), cv2.COLOR_GRAY2RGB)

    for (x, y, w, h) in boxes:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    plt.imshow(img)
    plt.show()

# %%
output_dir = '/content/drive/MyDrive/GPR/tar/görseller/'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for i in range(len(pred_mask1)):
    pred1 = (pred_mask1[i].reshape(image_sizeX, image_sizeY) * 255).astype(np.uint8)
    pred2 = (pred_mask2[i].reshape(image_sizeX, image_sizeY) * 255).astype(np.uint8)

    Image.fromarray(pred1).convert('L').save(f'{output_dir}/1pred_{i+1}.png')
    Image.fromarray(pred2).convert('L').save(f'{output_dir}/2pred_{i+1}.png')

# %%
model.load_weights(model_path)
model.evaluate(x=test_data, y=[test_mask1, test_mask2], batch_size=batch_size)
[test_pred1, test_pred2] = model.predict(test_data)
for i in range(len(test_data)):
    pred1 = test_pred1[i].reshape(image_sizeX, image_sizeY) * 255
    pred1 = Image.fromarray(pred1)
    pred1.convert('L').save('/content/drive/MyDrive/GPR/tar/görseller/1pred_%d.png'%(i+1))
    pred2 = test_pred2[i].reshape(image_sizeX, image_sizeY) * 255
    pred2 = Image.fromarray(pred2)
    pred2.convert('L').save('/content/drive/MyDrive/GPR/tar/görseller/2pred_%d.png'%(i+1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step - conv2d_49_loss: 0.0114 - conv2d_49_mae: 0.0254 - conv2d_99_loss: 8.5935e-04 - conv2d_99_mae: 0.0046 - loss: 0.0123
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
